# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\khushi pawar\Downloads\data_science_job.csv")

# %%
df.head(3)
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
#
#   major_discipline  experience company_size company_type  training_hours  \
# 0             STEM        20.0          NaN          NaN            36.0
# 1             STEM        15.0        50-99      Pvt Ltd            47.0
# 2             STEM         5.0          NaN          NaN            83.0
#
#    target
# 0     1.0
# 1     0.0
# 2     0.0

# %%
df.isnull().mean()*100
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     2.500261
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# training_hours             3.998330
# target                     0.000000
# dtype: float64

# %%
df.shape
# Out:
# (19158, 13)

# %%
col=[i for i in df.columns if df[i].isnull().mean()*100<5 and df[i].isnull().mean()*100>0]

# %%
df[col].sample(5)
# Out:
#        city_development_index enrolled_university education_level  experience  \
# 18157                   0.624       no_enrollment        Graduate        15.0
# 14741                   0.920       no_enrollment        Graduate        19.0
# 5058                    0.682       no_enrollment        Graduate        12.0
# 16559                   0.920       no_enrollment        Graduate         5.0
# 3954                    0.855       no_enrollment        Graduate        16.0
#
#        training_hours
# 18157             NaN
# 14741            55.0
# 5058             25.0
# 16559            85.0
# 3954             16.0

# %%
df['education_level'].value_counts()
# Out:
# education_level
# Graduate          11598
# Masters            4361
# High School        2017
# Phd                 414
# Primary School      308
# Name: count, dtype: int64

# %%
new_df=df[col].dropna()

# %%
new_df.shape
# Out:
# (17182, 5)

# %%
new_df.hist(bins=50,density=True,figsize=(12, 12))
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df['city_development_index'].hist(bins=50,ax=ax,density=True,color='blue')
plt.title('before')

new_df['city_development_index'].hist(bins=50,ax=ax,density=True,color='yellow')
plt.title("after")

plt.show()

# %%
fig=plt.figure()
ax=fig.add_subplot(111)

df['experience'].hist(bins=50,ax=ax,density=True,color='blue')
plt.title('before')

new_df['experience'].hist(bins=50,ax=ax,density=True,color='yellow')
plt.title("after")

plt.show()

# %%
fig=plt.figure()
ax=fig.add_subplot(111)

df['training_hours'].hist(bins=50,ax=ax,density=True,color='blue')
plt.title('before')

new_df['training_hours'].hist(bins=50,ax=ax,density=True,color='yellow')
plt.title("after")

plt.show()

# %%
fig=plt.figure()
ax=fig.add_subplot(111)

df['city_development_index'].plot.density(color='blue')

new_df['city_development_index'].plot.density(color='red')
# Out:
# <Axes: ylabel='Density'>

# %%
fig=plt.figure()
ax=fig.add_subplot(111)

df['experience'].plot.density(color='blue')

new_df['experience'].plot.density(color='red')
# Out:
# <Axes: ylabel='Density'>

# %%
fig=plt.figure()
ax=fig.add_subplot(111)

df['training_hours'].plot.density(color='blue')

new_df['training_hours'].plot.density(color='red')
# Out:
# <Axes: ylabel='Density'>

# %%
df.shape
# Out:
# (19158, 13)

# %%
a=df['education_level'].value_counts()

# %%
a
# Out:
# education_level
# Graduate          11598
# Masters            4361
# High School        2017
# Phd                 414
# Primary School      308
# Name: count, dtype: int64

# %%
new_df['education_level'].value_counts()
# Out:
# education_level
# Graduate          10650
# Masters            4022
# High School        1845
# Phd                 380
# Primary School      285
# Name: count, dtype: int64

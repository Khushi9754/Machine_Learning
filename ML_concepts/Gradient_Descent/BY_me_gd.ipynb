# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
X,y = make_regression(n_samples=100,n_features=1,n_informative=1,n_targets=1,noise=20)

# %%
X.shape
# Out:
# (100, 1)

# %%
li = LinearRegression()
li.fit(X,y)
y_pre = li.predict(X)

print(" m : ",li.coef_)
print(" b : ",li.intercept_)
# Out:
#  m :  [9.54186972]
#  b :  1.0928659979280908

# %%
class GDR:
    
    def __init__(self,learning_rate,epochs):
        
        self.m = 100
        self.b = -120
        self.n = learning_rate
        self.ep = epochs
        
    def fit(self,X,y):
        
        for i in range(self.ep):
            
            loss_b = -2 * np.sum(y - self.m*X.ravel() - self.b )
            loss_m = -2 * np.sum((y - self.m*X.ravel() - self.b)*X.ravel())
            
            self.b = self.b - self.n * loss_b
            self.m = self.m - self.n * loss_m
            
            
        print(" b : ",self.b)
        print(" m : ",self.m)
        
    def predict(self,X):
        
        y_pred = self.m*X + self.b
        print(y_pred)

# %%
lr = GDR(0.001,60)
lr.fit(X,y)
# Out:
#  b :  2.765833020760679
#  m :  72.37032044525894

# %%
y_pred = lr.predict(X)
# Out:
# [[  21.17152939]
#  [ -64.5637449 ]
#  [   8.37196583]
#  [  -6.84424166]
#  [  47.24090847]
#  [ -13.34156921]
#  [  65.02221896]
#  [ -40.13073722]
#  [ -29.15358426]
#  [ 105.78124053]
#  [   1.97704635]
#  [-100.68762774]
#  [  78.77593734]
#  [ -64.30799217]
#  [-110.1427589 ]
#  [   1.74415817]
#  [ -67.66861401]
#  [ 134.08184403]
#  [  20.65578393]
#  [ 150.45758775]
#  [  89.2520046 ]
#  [ -55.9210581 ]
#  [  77.98570786]
#  [  37.94565464]
#  [ -76.63987994]
#  [ -90.63244351]
#  [ -48.71437921]
#  [  42.93997061]
#  [ -27.47245237]
#  [  13.71277805]
#  [-194.70326026]
#  [ 134.44151169]
#  [  98.6971812 ]
#  [  32.74394742]
#  [  48.70654868]
#  [  48.43531583]
#  [  19.9987321 ]
#  [  -4.93400176]
#  [   9.26395245]
#  [ 119.90648514]
#  [ -60.49910124]
#  [  -6.35224884]
#  [  61.23336523]
#  [ -79.55655942]
#  [  61.12889716]
#  [ -85.06550854]
#  [  26.44927892]
#  [ -84.4759822 ]
#  [  39.24164094]
#  [ 111.8046378 ]
#  [ -45.37767405]
#  [ 124.49346677]
#  [ -43.41123206]
#  [ -90.89734182]
#  [  24.63100001]
#  [ -11.39893322]
#  [ -23.72729354]
#  [ -73.57604814]
#  [  70.01190011]
#  [   5.46653047]
#  [  72.21181988]
#  [  12.7625661 ]
#  [ -57.17422478]
#  [ 138.36723406]
#  [-164.03448942]
#  [  -6.44012342]
#  [  80.37663143]
#  [ -48.98264494]
#  [  43.5644095 ]
#  [  13.3002643 ]
#  [  30.40082235]
#  [ -35.3195873 ]
#  [  27.29061703]
#  [  79.97924149]
#  [ -20.31921874]
#  [ -23.59164891]
#  [  30.00750514]
#  [ -32.54425013]
#  [   8.78813288]
#  [  23.80995612]
#  [ 111.95187976]
#  [-155.25449327]
#  [-167.24382296]
#  [  80.0884468 ]
#  [  20.12443073]
#  [  77.66074978]
#  [ -84.91691943]
#  [ -13.56373226]
#  [ -62.06728103]
#  [ -56.051332  ]
#  [-117.0931986 ]
#  [  24.81829005]
#  [  21.91207747]
#  [  83.78105456]
#  [  44.98351586]
#  [  -1.42808174]
#  [  85.12855759]
#  [  46.93297734]
#  [ -67.77621027]
#  [ -33.66118509]]

# %%
y_pre
# Out:
# array([  21.17207121,  -64.56295057,    8.37254535,   -6.84361732,
#          47.24137352,  -13.34092574,   65.02263163,  -40.13001485,
#         -29.15289421,  105.78153316,    1.9776447 , -100.68672701,
#          78.77630951,  -64.30719859, -110.14183033,    1.74475721,
#         -67.66781054,  134.08205331,   20.65632727,  150.45774879,
#          89.25234591,  -55.92028922,   77.98608235,   37.94614706,
#         -76.63905004,  -90.6315724 ,  -48.71363156,   42.94044832,
#         -27.47176728,   13.71334184, -194.70208263,  134.44171991,
#          98.69749469,   32.74445516,   48.70700941,   48.43577736,
#          19.99927738,   -4.93338305,    9.26452934,  119.90673617,
#         -60.49831888,   -6.35162595,   61.23378906,  -79.55572093,
#          61.12932129,  -85.06465383,   26.4498052 ,  -84.47512923,
#          39.24212954,  111.80491268,  -45.37693622,  124.49370429,
#         -43.41050003,  -90.89646992,   24.63153164,  -11.39829547,
#         -23.72661948,  -73.57522726,   70.01229809,    5.46711855,
#          72.21221138,   12.76313269,  -57.17345221,  138.36743072,
#        -164.03340213,   -6.43950028,   80.37699888,  -48.9818965 ,
#          43.56488537,   13.3008293 ,   30.40133699,  -35.3188791 ,
#          27.29114083,   79.97961011,  -20.31855472,  -23.59097525,
#          30.00802094,  -32.5435501 ,    8.78871117,   23.81049017,
#         111.95215421, -155.25343183, -167.24272621,   80.08881509,
#          20.12497564,   77.66112522,  -84.91606516,  -13.56308813,
#         -62.06649405,  -56.05056274, -117.09224956,   24.81882113,
#          21.91261711,   83.78141198,   44.98398755,   -1.42747335,
#          85.12891104,   46.93344329,  -67.77540647,  -33.66048177])

# %%
import pandas as pd
data={
    "name":["khushi","palak","nidhi","pooja"],
    "gender":["female","-","#",None]}
df=pd.DataFrame(data)
df
# Out:
#      name  gender
# 0  khushi  female
# 1   palak       -
# 2   nidhi       #
# 3   pooja    None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   gender  3 non-null      object
# dtypes: object(2)
# memory usage: 196.0+ bytes

# %%
df1=pd.read_csv("C:\\Users\\khushi pawar\\Downloads\\matches - matches.csv").info()
df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
import pandas as pd
df1=pd.read_csv("C:\\Users\\khushi pawar\\Downloads\\matches - matches.csv",na_values=["Indore","Hyderabad"])
df1.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017        NaN  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017        NaN  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
d1=pd.read_csv("C:\\Users\\khushi pawar\\Downloads\\matches - matches.csv",chunksize=318)
for chunks in d1:
    print(chunks)
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017           Pune  06-04-2017               Mumbai Indians
# 2      3    2017         Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017         Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..   ...     ...            ...         ...                          ...
# 313  314    2012         Jaipur  08-04-2012             Rajasthan Royals
# 314  315    2012           Pune  08-04-2012                Pune Warriors
# 315  316    2012  Visakhapatnam  09-04-2012              Deccan Chargers
# 316  317    2012      Bangalore  10-04-2012        Kolkata Knight Riders
# 317  318    2012          Delhi  10-04-2012          Chennai Super Kings
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
import pandas as pd
data=pd.read_json(r"C:\Users\khushi pawar\Downloads\test.json")
data.sample(5)
# Out:
#           id    cuisine                                        ingredients
# 38427  17549       thai  [gai lan, garlic, sugar, oyster sauce, fish sa...
# 20979  31917    chinese  [soy sauce, Shaoxing wine, scallions, japanese...
# 33594  36592  brazilian  [brown sugar, olive oil, garlic cloves, cashew...
# 3151   19358    chinese  [unsalted butter, gai lan, chinese five-spice ...
# 25658  46654    italian  [dried basil, linguine, green bell pepper, sun...

# %%
import pandas as pd 
df=pd.read_json(r"C:\Users\khushi pawar\Downloads\train.json",lines=True)
df
# Out:
#    id     name  score
# 0   1    Alice     85
# 1   2      Bob     90
# 2   3  Charlie     78
# 3   4    David     92
# 4   5      Eve     88
# 5   6    Frank     76
# 6   7    Grace     95
# 7   8   Hannah     82
# 8   9     Ivan     89
# 9  10     Judy     91

# %%
df=pd.read_json(r"C:\Users\khushi pawar\Downloads\train.json",lines=True,nrows=4)

# %%
df
# Out:
#    id     name  score
# 0   1    Alice     85
# 1   2      Bob     90
# 2   3  Charlie     78
# 3   4    David     92

# %%
import pandas as pd 
import requests
data1=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=a6fc8171348a8d1e2f4dfceadfa25c19&language=en-US&page=1")

# %%
pd.DataFrame(data1.json())
# Out:
#     page                                            results  total_pages  \
# 0      1  {'adult': False, 'backdrop_path': '/pNjh59JSxC...          516
# 1      1  {'adult': False, 'backdrop_path': '/htuuuEwAvD...          516
# 2      1  {'adult': False, 'backdrop_path': '/kGzFbGhp99...          516
# 3      1  {'adult': False, 'backdrop_path': '/zb6fM1CX41...          516
# 4      1  {'adult': False, 'backdrop_path': '/bxgTSUenZD...          516
# 5      1  {'adult': False, 'backdrop_path': '/ukfI9QkU1a...          516
# 6      1  {'adult': False, 'backdrop_path': '/enNubozHn9...          516
# 7      1  {'adult': False, 'backdrop_path': '/rRs4eLjEuU...          516
# 8      1  {'adult': False, 'backdrop_path': '/vxJ08Svwom...          516
# 9      1  {'adult': False, 'backdrop_path': '/hiKmpZMGZs...          516
# 10     1  {'adult': False, 'backdrop_path': '/2u7zbn8Eud...          516
# 11     1  {'adult': False, 'backdrop_path': '/suaEOtk1N1...          516
# ...

# %%
df1=pd.DataFrame(data1.json()['results'])[['id','title','popularity','release_date','vote_average','vote_count']]

# %%
df1
# Out:
#         id                                          title  popularity  \
# 0      278                       The Shawshank Redemption     27.8702
# 1      238                                  The Godfather     27.1466
# 2      240                          The Godfather Part II     16.9484
# 3      424                               Schindler's List     18.4556
# 4      389                                   12 Angry Men     12.7383
# 5      129                                  Spirited Away     23.7155
# 6      155                                The Dark Knight     30.9926
# 7    19404                    Dilwale Dulhania Le Jayenge      7.3593
# 8      497                                 The Green Mile     18.1485
# 9   496243                                       Parasite     21.4447
# 10     122  The Lord of the Rings: The Return of the King     22.9557
# 11     680                                   Pulp Fiction     20.3106
# ...

# %%
df1.shape
# Out:
# (20, 6)

# %%
new_df=pd.DataFrame()
new_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,516):
    data1=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=a6fc8171348a8d1e2f4dfceadfa25c19&language=en-US&page={}".format(i))
    df1=pd.DataFrame(data1.json()['results'])[['id','title','popularity','release_date','vote_average','vote_count']]
    #new_df.concat(df1,ignore_index=True)
    new_df = pd.concat([new_df, df1], ignore_index=True)
print(new_df.head())

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)

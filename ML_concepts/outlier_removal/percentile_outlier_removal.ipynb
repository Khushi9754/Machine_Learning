# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\khushi pawar\Downloads\weight-height.csv")
df1 = pd.read_csv(r"C:\Users\khushi pawar\Downloads\weight-height.csv")

# %%
df.sample(5)
# Out:
#       Gender     Height      Weight
# 8390  Female  60.741396  118.418728
# 2961    Male  68.650218  176.030067
# 9379  Female  64.649432  140.896248
# 9452  Female  65.793651  140.179483
# 9592  Female  62.511902  139.451959

# %%
sns.distplot(df['Height'],kde=True)
# Out:
# C:\Users\khushi pawar\AppData\Local\Temp\ipykernel_24892\1170973858.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Height'],kde=True)
# C:\Users\khushi pawar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.distplot(df['Weight'],kde=True)
# Out:
# C:\Users\khushi pawar\AppData\Local\Temp\ipykernel_24892\1241272107.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'],kde=True)
# C:\Users\khushi pawar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
df['Weight'].describe()
# Out:
# count    10000.000000
# mean       161.440357
# std         32.108439
# min         64.700127
# 25%        135.818051
# 50%        161.212928
# 75%        187.169525
# max        269.989699
# Name: Weight, dtype: float64

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
sns.boxplot(x=df['Weight'])
# Out:
# <Axes: xlabel='Weight'>

# %%
upper = df['Weight'].quantile(0.99)
lower = df['Weight'].quantile(0.01)

# %%
upper
# Out:
# 227.43736983602577

# %%
lower
# Out:
# 97.03287365980914

# %%
df[ (df['Weight']<lower) | (df['Weight']>upper) ]
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 23      Male  75.205974  228.761781
# 82      Male  73.826127  237.916736
# 190     Male  76.709835  235.035419
# 191     Male  72.571121  230.560535
# ...      ...        ...         ...
# 9761  Female  56.975279   90.341784
# 9775  Female  60.025950   87.035416
# 9825  Female  55.979198   85.417534
# 9895  Female  57.740192   93.652957
# 9989  Female  60.955084   95.686674
#
# [200 rows x 3 columns]

# %%
new_df = df[ (df['Weight']>lower) & (df['Weight']<upper) ]

# %%
new_df
# Out:
#       Gender     Height      Weight
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# 5       Male  67.253016  152.212156
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [9800 rows x 3 columns]

# %%
sns.boxplot(x=new_df['Weight'])
# Out:
# <Axes: xlabel='Weight'>

# %%
sns.boxplot(x=df1['Height'])
# Out:
# <Axes: xlabel='Height'>

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
upper_limit = df1['Height'].quantile(0.99)
lower_limit = df1['Height'].quantile(0.01)

# %%
upper_limit
# Out:
# 74.7857900583366

# %%
lower_limit
# Out:
# 58.13441158671655

# %%
df1[ (df1['Height']>upper_limit) | (df1['Height']<lower_limit) ]
# Out:
#       Gender     Height      Weight
# 23      Male  75.205974  228.761781
# 190     Male  76.709835  235.035419
# 197     Male  75.944460  231.924749
# 202     Male  75.140821  224.124271
# 215     Male  74.795375  232.635403
# ...      ...        ...         ...
# 9761  Female  56.975279   90.341784
# 9825  Female  55.979198   85.417534
# 9895  Female  57.740192   93.652957
# 9904  Female  57.028857  101.202551
# 9978  Female  57.375759  114.192209
#
# [200 rows x 3 columns]

# %%
df1 = df1[ (df1['Height']<upper_limit) & (df1['Height']>lower_limit) ]

# %%
df1
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [9800 rows x 3 columns]

# %%
sns.boxplot(x=df1['Height'])
# Out:
# <Axes: xlabel='Height'>

# %%
df1['Height'].describe()
# Out:
# count    9800.000000
# mean       66.364366
# std         3.645075
# min        58.134496
# 25%        63.577162
# 50%        66.318070
# 75%        69.119896
# max        74.785714
# Name: Height, dtype: float64

# %% [markdown]
# **capping --> winsoziration**

# %%
df['Height']=np.where(
    df['Height']>upper_limit,
    upper_limit,
    np.where(
        df['Height']<lower_limit,
        lower_limit,
        df['Height']
    )
)

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.366281
# std          3.795717
# min         58.134412
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         74.785790
# Name: Height, dtype: float64
